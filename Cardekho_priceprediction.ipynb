# %%
import pandas as pd

# %%
chennaidf=pd.read_csv("C:/Users/hp/Desktop/Cardekho_Project/chennai_cars.csv",encoding="ISO-8859-1")

# %%
chennaidf
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
chennaidf.iloc[0,0] #To view the single column value
# Out:
# "{'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '20,000', 'transmission': 'Automatic', 'ownerNo': 1, 'owner': '1st Owner', 'oem': 'Kia', 'model': 'Kia Sonet', 'modelYear': 2022, 'centralVariantId': 8654, 'variantName': 'Turbo DCT Anniversary Edition', 'price': '? 11.50 Lakh', 'priceActual': '', 'priceSaving': '', 'priceFixedText': None, 'trendingText': {'imgUrl': 'https://stimg.cardekho.com/used-cars/common/icons/trending.svg', 'heading': 'Trending Car!', 'desc': 'High chances of sale in next 6 days'}}"

# %%
import json

# %%
chennaidf["new_car_detail"]=chennaidf["new_car_detail"].apply(lambda i:json.loads(i.replace("'",'"').replace("None","1")))
chennaidf["new_car_detail"]
# Out:
# 0       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1       {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2       {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4       {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#                               ...
# 1414    {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416    {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417    {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418    {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# Name: new_car_detail, Length: 1419, dtype: object

# %%
newdf=pd.DataFrame(chennaidf["new_car_detail"].to_list())
newdf
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# ...

# %%
x=pd.json_normalize(chennaidf["new_car_detail"])
x
# Out:
#       it      ft         bt      km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV  20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans  20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV  30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback  59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback  50,000       Manual        1  1st Owner
# ...   ..     ...        ...     ...          ...      ...        ...
# 1414   0  Petrol  Hatchback  42,891    Automatic        1  1st Owner
# 1415   0  Diesel        SUV  59,100       Manual        1  1st Owner
# 1416   0  Petrol        SUV  55,913    Automatic        1  1st Owner
# 1417   0  Diesel        SUV  65,000    Automatic        1  1st Owner
# 1418   0  Diesel      Sedan  60,000    Automatic        1  1st Owner
#
#              oem              model  modelYear  centralVariantId  \
# 0            Kia          Kia Sonet       2022              8654
# ...

# %%
df1=pd.read_csv("C:/Users/hp/Desktop/Cardekho_Project/chennai_cars.csv",encoding="ISO-8859-1")
df2=pd.read_csv("C:/Users/hp/Desktop/Cardekho_Project/delhi_cars.csv",encoding="ISO-8859-1")
df3=pd.read_csv("C:/Users/hp/Desktop/Cardekho_Project/jaipur_cars.csv",encoding="ISO-8859-1")
df4=pd.read_csv("C:/Users/hp/Desktop/Cardekho_Project/kolkata_cars.csv",encoding="ISO-8859-1")
df5=pd.read_csv("C:/Users/hp/Desktop/Cardekho_Project/bangalore_cars.csv",encoding="ISO-8859-1")

# %%
df1['City']=pd.Series(dtype='object')

# %%
df1["City"].fillna(value='Chennai',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10796\2777014852.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["City"].fillna(value='Chennai',inplace=True)

# %%
df2['City']=pd.Series(dtype='object')
df2["City"].fillna(value='Delhi',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10796\1408733402.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["City"].fillna(value='Delhi',inplace=True)

# %%
df3['City']=pd.Series(dtype='object')
df3["City"].fillna(value='Jaipur',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10796\3273080738.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3["City"].fillna(value='Jaipur',inplace=True)

# %%
df4['City']=pd.Series(dtype='object')
df4["City"].fillna(value='Kolkata',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10796\3578913893.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df4["City"].fillna(value='Kolkata',inplace=True)

# %%
df5['City']=pd.Series(dtype='object')
df5["City"].fillna(value='Bangalore',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10796\4064317829.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df5["City"].fillna(value='Bangalore',inplace=True)

# %%
df5
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
df=pd.concat([df1,df2,df3,df4,df5])

# %%
df=df.reset_index()

# %%
df
# Out:
#       index                                     new_car_detail  \
# 0         0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1         1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2         2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3         3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4         4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...     ...                                                ...
# 6881   1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 6882   1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 6883   1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 6884   1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 6885   1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
df["new_car_detail"]=df["new_car_detail"].apply(lambda i:json.loads(i.replace("'",'"').replace("None","1")))
df
# Out:
#       index                                     new_car_detail  \
# 0         0  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1         1  {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2         2  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3         3  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4         4  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...     ...                                                ...
# 6881   1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 6882   1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 6883   1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 6884   1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 6885   1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
df["new_car_overview"]=df["new_car_overview"].apply(lambda i:json.loads(i.replace("'",'"').replace("None","1")))
df["new_car_feature"]=df["new_car_feature"].apply(lambda i:json.loads(i.replace("'",'"').replace("None","1")))
df["new_car_specs"]=df["new_car_specs"].apply(lambda i:json.loads(i.replace("'",'"').replace("None","1")))

# %%
df["new_car_overview"]
# Out:
# 0       {'heading': 'Car overview', 'top': [{'key': 'R...
# 1       {'heading': 'Car overview', 'top': [{'key': 'R...
# 2       {'heading': 'Car overview', 'top': [{'key': 'R...
# 3       {'heading': 'Car overview', 'top': [{'key': 'R...
# 4       {'heading': 'Car overview', 'top': [{'key': 'R...
#                               ...
# 6881    {'heading': 'Car overview', 'top': [{'key': 'R...
# 6882    {'heading': 'Car overview', 'top': [{'key': 'R...
# 6883    {'heading': 'Car overview', 'top': [{'key': 'R...
# 6884    {'heading': 'Car overview', 'top': [{'key': 'R...
# 6885    {'heading': 'Car overview', 'top': [{'key': 'R...
# Name: new_car_overview, Length: 6886, dtype: object

# %%
newdf1=pd.json_normalize(df["new_car_detail"]) # first column to 19 columns
newdf1
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  centralVariantId  \
# ...

# %%
newdf2=pd.json_normalize(df["new_car_overview"]) # second column to 10 columns
newdf2
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2021',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# ...            ...                                                ...
# 6881  Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 6882  Car overview  [{'key': 'Registration Year', 'value': 'Jun 20...
# 6883  Car overview  [{'key': 'Registration Year', 'value': 'Sept 2...
# 6884  Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...
# 6885  Car overview  [{'key': 'Registration Year', 'value': 'May 20...
#
#       bottomData
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...

# %%
newdf2
# Out:
#            heading                                                top  \
# 0     Car overview  [{'key': 'Registration Year', 'value': '2022',...
# 1     Car overview  [{'key': 'Registration Year', 'value': 'Feb 20...
# 2     Car overview  [{'key': 'Registration Year', 'value': '2021',...
# 3     Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 4     Car overview  [{'key': 'Registration Year', 'value': '2015',...
# ...            ...                                                ...
# 6881  Car overview  [{'key': 'Registration Year', 'value': 'May 20...
# 6882  Car overview  [{'key': 'Registration Year', 'value': 'Jun 20...
# 6883  Car overview  [{'key': 'Registration Year', 'value': 'Sept 2...
# 6884  Car overview  [{'key': 'Registration Year', 'value': 'Dec 20...
# 6885  Car overview  [{'key': 'Registration Year', 'value': 'May 20...
#
#       bottomData
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...

# %%
a=pd.json_normalize(newdf2["top"])

# %%
a
# Out:
#                                                       0  \
# 0     {'key': 'Registration Year', 'value': '2022', ...
# 1     {'key': 'Registration Year', 'value': 'Feb 201...
# 2     {'key': 'Registration Year', 'value': '2021', ...
# 3     {'key': 'Registration Year', 'value': 'May 201...
# 4     {'key': 'Registration Year', 'value': '2015', ...
# ...                                                 ...
# 6881  {'key': 'Registration Year', 'value': 'May 201...
# 6882  {'key': 'Registration Year', 'value': 'Jun 200...
# 6883  {'key': 'Registration Year', 'value': 'Sept 20...
# 6884  {'key': 'Registration Year', 'value': 'Dec 201...
# 6885  {'key': 'Registration Year', 'value': 'May 201...
#
#                                                       1  \
# 0     {'key': 'Insurance Validity', 'value': 'Third ...
# 1     {'key': 'Insurance Validity', 'value': 'Compre...
# 2     {'key': 'Insurance Validity', 'value': 'Third ...
# 3     {'key': 'Insurance Validity', 'value': 'Compre...
# ...

# %%
regyr=pd.json_normalize(a[0])

# %%
regyr
# Out:
#                     key      value  \
# 0     Registration Year       2022
# 1     Registration Year   Feb 2015
# 2     Registration Year       2021
# 3     Registration Year   May 2015
# 4     Registration Year       2015
# ...                 ...        ...
# 6881  Registration Year   May 2012
# 6882  Registration Year   Jun 2008
# 6883  Registration Year  Sept 2014
# 6884  Registration Year   Dec 2018
# 6885  Registration Year   May 2017
#
#                                                    icon
# 0     https://images10.gaadi.com/listing/vdp/co/v1/r...
# 1     https://images10.gaadi.com/listing/vdp/co/v1/r...
# 2     https://images10.gaadi.com/listing/vdp/co/v1/r...
# 3     https://images10.gaadi.com/listing/vdp/co/v1/r...
# 4     https://images10.gaadi.com/listing/vdp/co/v1/r...
# ...                                                 ...
# 6881  https://images10.gaadi.com/listing/vdp/co/v1/r...
# 6882  https://images10.gaadi.com/listing/vdp/co/v1/r...
# ...

# %%
insurance=pd.json_normalize(a[1])
insurance
# Out:
#                      key                  value  \
# 0     Insurance Validity  Third Party insurance
# 1     Insurance Validity          Comprehensive
# 2     Insurance Validity  Third Party insurance
# 3     Insurance Validity          Comprehensive
# 4     Insurance Validity  Third Party insurance
# ...                  ...                    ...
# 6881  Insurance Validity          Comprehensive
# 6882  Insurance Validity  Third Party insurance
# 6883  Insurance Validity          Comprehensive
# 6884  Insurance Validity          Comprehensive
# 6885  Insurance Validity          Comprehensive
#
#                                                    icon
# 0     https://images10.gaadi.com/listing/vdp/co/v1/i...
# 1     https://images10.gaadi.com/listing/vdp/co/v1/i...
# 2     https://images10.gaadi.com/listing/vdp/co/v1/i...
# 3     https://images10.gaadi.com/listing/vdp/co/v1/i...
# 4     https://images10.gaadi.com/listing/vdp/co/v1/i...
# ...

# %%
insurance["value"]
# Out:
# 0       Third Party insurance
# 1               Comprehensive
# 2       Third Party insurance
# 3               Comprehensive
# 4       Third Party insurance
#                 ...
# 6881            Comprehensive
# 6882    Third Party insurance
# 6883            Comprehensive
# 6884            Comprehensive
# 6885            Comprehensive
# Name: value, Length: 6886, dtype: object

# %%
newdf3=pd.json_normalize(df["new_car_feature"]) # third column to 9 columns cosmetic

# %%
newdf3
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Low Fuel Warning Light'}, {'value'...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 6881  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 6882  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 6883  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 6884  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 6885  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# ...

# %%
b=pd.json_normalize(newdf3["top"])
b
# Out:
#                                         0  \
# 0             {'value': 'Power Steering'}
# 1     {'value': 'Low Fuel Warning Light'}
# 2             {'value': 'Power Steering'}
# 3             {'value': 'Power Steering'}
# 4             {'value': 'Power Steering'}
# ...                                   ...
# 6881          {'value': 'Power Steering'}
# 6882          {'value': 'Power Steering'}
# 6883          {'value': 'Power Steering'}
# 6884          {'value': 'Power Steering'}
# 6885          {'value': 'Power Steering'}
#
#                                         1                             2  \
# 0        {'value': 'Power Windows Front'}  {'value': 'Air Conditioner'}
# 1     {'value': 'Accessory Power Outlet'}           {'value': 'Heater'}
# 2        {'value': 'Power Windows Front'}  {'value': 'Air Conditioner'}
# 3        {'value': 'Power Windows Front'}  {'value': 'Air Conditioner'}
# 4        {'value': 'Power Windows Front'}  {'value': 'Air Conditioner'}
# ...

# %%
c=pd.json_normalize(newdf3["data"])
c
# Out:
#                                                       0  \
# 0     {'heading': 'Comfort & Convenience', 'subHeadi...
# 1     {'heading': 'Comfort & Convenience', 'subHeadi...
# 2     {'heading': 'Comfort & Convenience', 'subHeadi...
# 3     {'heading': 'Comfort & Convenience', 'subHeadi...
# 4     {'heading': 'Comfort & Convenience', 'subHeadi...
# ...                                                 ...
# 6881  {'heading': 'Comfort & Convenience', 'subHeadi...
# 6882  {'heading': 'Comfort & Convenience', 'subHeadi...
# 6883  {'heading': 'Comfort & Convenience', 'subHeadi...
# 6884  {'heading': 'Comfort & Convenience', 'subHeadi...
# 6885  {'heading': 'Comfort & Convenience', 'subHeadi...
#
#                                                       1  \
# 0     {'heading': 'Interior', 'subHeading': 'Interio...
# 1     {'heading': 'Interior', 'subHeading': 'Interio...
# 2     {'heading': 'Interior', 'subHeading': 'Interio...
# 3     {'heading': 'Interior', 'subHeading': 'Interio...
# ...

# %%
newdf4=pd.json_normalize(df["new_car_specs"]) # fourth column to 9 columns 
newdf4
# Out:
#              heading                                                top  \
# 0     Specifications  [{'key': 'Engine', 'value': '998 CC'}, {'key':...
# 1     Specifications  [{'key': 'Mileage', 'value': '15.37 kmpl'}, {'...
# 2     Specifications  [{'key': 'Mileage', 'value': '20 kmpl'}, {'key...
# 3     Specifications  [{'key': 'Mileage', 'value': '19.81 kmpl'}, {'...
# 4     Specifications  [{'key': 'Mileage', 'value': '18.7 kmpl'}, {'k...
# ...              ...                                                ...
# 6881  Specifications  [{'key': 'Mileage', 'value': '12.55 kmpl'}, {'...
# 6882  Specifications  [{'key': 'Mileage', 'value': '15 kmpl'}, {'key...
# 6883  Specifications  [{'key': 'Mileage', 'value': '19.4 kmpl'}, {'k...
# 6884  Specifications  [{'key': 'Mileage', 'value': '22.54 kmpl'}, {'...
# 6885  Specifications  [{'key': 'Mileage', 'value': '18.9 kmpl'}, {'k...
#
#                                                    data commonIcon
# ...

# %%
d=pd.json_normalize(newdf4["top"])
d
# Out:
#                                               0  \
# 0          {'key': 'Engine', 'value': '998 CC'}
# 1     {'key': 'Mileage', 'value': '15.37 kmpl'}
# 2        {'key': 'Mileage', 'value': '20 kmpl'}
# 3     {'key': 'Mileage', 'value': '19.81 kmpl'}
# 4      {'key': 'Mileage', 'value': '18.7 kmpl'}
# ...                                         ...
# 6881  {'key': 'Mileage', 'value': '12.55 kmpl'}
# 6882     {'key': 'Mileage', 'value': '15 kmpl'}
# 6883   {'key': 'Mileage', 'value': '19.4 kmpl'}
# 6884  {'key': 'Mileage', 'value': '22.54 kmpl'}
# 6885   {'key': 'Mileage', 'value': '18.9 kmpl'}
#
#                                                1  \
# 0     {'key': 'Max Power', 'value': '118.36bhp'}
# 1          {'key': 'Engine', 'value': '1196 CC'}
# 2           {'key': 'Engine', 'value': '999 CC'}
# 3          {'key': 'Engine', 'value': '1086 CC'}
# 4          {'key': 'Engine', 'value': '1199 CC'}
# ...                                          ...
# ...

# %%
mileage=pd.json_normalize(d[0])
mileage
# Out:
#           key       value
# 0      Engine      998 CC
# 1     Mileage  15.37 kmpl
# 2     Mileage     20 kmpl
# 3     Mileage  19.81 kmpl
# 4     Mileage   18.7 kmpl
# ...       ...         ...
# 6881  Mileage  12.55 kmpl
# 6882  Mileage     15 kmpl
# 6883  Mileage   19.4 kmpl
# 6884  Mileage  22.54 kmpl
# 6885  Mileage   18.9 kmpl
#
# [6886 rows x 2 columns]

# %%
engine=pd.json_normalize(d[1])
engine
# Out:
#             key      value
# 0     Max Power  118.36bhp
# 1        Engine    1196 CC
# 2        Engine     999 CC
# 3        Engine    1086 CC
# 4        Engine    1199 CC
# ...         ...        ...
# 6881     Engine    2982 CC
# 6882     Engine    1586 CC
# 6883     Engine    1198 CC
# 6884     Engine    1396 CC
# 6885     Engine    1197 CC
#
# [6886 rows x 2 columns]

# %%
e=pd.json_normalize(newdf4["data"])
e
# Out:
#                                                       0  \
# 0     {'heading': 'Engine and Transmission', 'subHea...
# 1     {'heading': 'Engine and Transmission', 'subHea...
# 2     {'heading': 'Engine and Transmission', 'subHea...
# 3     {'heading': 'Engine and Transmission', 'subHea...
# 4     {'heading': 'Engine and Transmission', 'subHea...
# ...                                                 ...
# 6881  {'heading': 'Engine and Transmission', 'subHea...
# 6882  {'heading': 'Engine and Transmission', 'subHea...
# 6883  {'heading': 'Engine and Transmission', 'subHea...
# 6884  {'heading': 'Engine and Transmission', 'subHea...
# 6885  {'heading': 'Engine and Transmission', 'subHea...
#
#                                                       1  \
# 0     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 1     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 2     {'heading': 'Dimensions & Capacity', 'subHeadi...
# 3     {'heading': 'Dimensions & Capacity', 'subHeadi...
# ...

# %%
finaldf=pd.concat([newdf1,regyr],axis=1)

# %%
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...         price priceActual  \
# ...

# %%
finaldf=finaldf.drop(["key"],axis=1)

# %%
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...  \
# 0         Kia          Kia Sonet       2022  ...
# ...

# %%
finaldf.rename(columns={'value':'RegistrationYear'},inplace=True)
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...  \
# 0         Kia          Kia Sonet       2022  ...
# ...

# %%
finaldf=pd.concat([finaldf,insurance["value"]],axis=1)

# %%
finaldf.rename(columns={'value':'Insurance'},inplace=True)
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...         price priceActual  \
# ...

# %%
finaldf=pd.concat([finaldf,engine["value"]],axis=1)

# %%
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...  priceActual priceSaving  \
# ...

# %%
finaldf.rename(columns={'value':'Engine'},inplace=True)
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...  priceActual priceSaving  \
# ...

# %%
finaldf=pd.concat([finaldf,mileage["value"]],axis=1)

# %%
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...  priceSaving priceFixedText  \
# ...

# %%
finaldf.rename(columns={'value':'Mileage'},inplace=True)
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...  priceSaving priceFixedText  \
# ...

# %%
finaldf=pd.concat([finaldf,df["City"]],axis=1)

# %%
finaldf
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol        SUV    20,000    Automatic        1  1st Owner
# 1      0  Petrol   Minivans    20,687       Manual        1  1st Owner
# 2      0  Petrol        SUV    30,000       Manual        1  1st Owner
# 3      0  Petrol  Hatchback    59,247       Manual        1  1st Owner
# 4      0  Petrol  Hatchback    50,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 6881   0  Diesel        SUV  1,56,039       Manual        2  2nd Owner
# 6882   0  Petrol      Sedan    56,000       Manual        2  2nd Owner
# 6883   0  Petrol  Hatchback    42,000       Manual        2  2nd Owner
# 6884   0  Diesel  Hatchback    93,003       Manual        1  1st Owner
# 6885   0  Petrol  Hatchback    36,000    Automatic        2  2nd Owner
#
#           oem              model  modelYear  ...  priceFixedText  \
# ...

# %%
finaldf.columns
# Out:
# Index(['it', 'ft', 'bt', 'km', 'transmission', 'ownerNo', 'owner', 'oem',
#        'model', 'modelYear', 'centralVariantId', 'variantName', 'price',
#        'priceActual', 'priceSaving', 'priceFixedText', 'trendingText.imgUrl',
#        'trendingText.heading', 'trendingText.desc', 'RegistrationYear', 'icon',
#        'Insurance', 'Engine', 'Mileage', 'City'],
#       dtype='object')

# %%
finaldf["icon"]
# Out:
# 0       https://images10.gaadi.com/listing/vdp/co/v1/r...
# 1       https://images10.gaadi.com/listing/vdp/co/v1/r...
# 2       https://images10.gaadi.com/listing/vdp/co/v1/r...
# 3       https://images10.gaadi.com/listing/vdp/co/v1/r...
# 4       https://images10.gaadi.com/listing/vdp/co/v1/r...
#                               ...
# 6881    https://images10.gaadi.com/listing/vdp/co/v1/r...
# 6882    https://images10.gaadi.com/listing/vdp/co/v1/r...
# 6883    https://images10.gaadi.com/listing/vdp/co/v1/r...
# 6884    https://images10.gaadi.com/listing/vdp/co/v1/r...
# 6885    https://images10.gaadi.com/listing/vdp/co/v1/r...
# Name: icon, Length: 6886, dtype: object

# %%
finaldf=finaldf.drop(["it","owner"],axis=1)

# %%
finaldf=finaldf.drop(["centralVariantId","variantName","trendingText.imgUrl","trendingText.heading","trendingText.desc","icon"],axis=1)

# %%
finaldf=finaldf.drop(["priceActual","priceSaving","priceFixedText"],axis=1)

# %%
finaldf=finaldf.drop(["RegistrationYear","model"],axis=1)

# %%
finaldf
# Out:
#           ft         bt        km transmission  ownerNo      oem  modelYear  \
# 0     Petrol        SUV    20,000    Automatic        1      Kia       2022
# 1     Petrol   Minivans    20,687       Manual        1   Maruti       2015
# 2     Petrol        SUV    30,000       Manual        1   Nissan       2021
# 3     Petrol  Hatchback    59,247       Manual        1  Hyundai       2015
# 4     Petrol  Hatchback    50,000       Manual        1    Honda       2015
# ...      ...        ...       ...          ...      ...      ...        ...
# 6881  Diesel        SUV  1,56,039       Manual        2   Toyota       2012
# 6882  Petrol      Sedan    56,000       Manual        2   Maruti       2008
# 6883  Petrol  Hatchback    42,000       Manual        2    Honda       2014
# 6884  Diesel  Hatchback    93,003       Manual        1  Hyundai       2018
# 6885  Petrol  Hatchback    36,000    Automatic        2  Hyundai       2017
#
# ...

# %%
finaldf=finaldf.drop(["Insurance"],axis=1)

# %%
finaldf["bt"].unique()
# Out:
# array(['SUV', 'Minivans', 'Hatchback', 'Sedan', 'MUV', 'Hybrids', 'Coupe',
#        'Convertibles', '', 'Wagon', 'Pickup Trucks'], dtype=object)

# %%
finaldf["oem"].unique()
# Out:
# array(['Kia', 'Maruti', 'Nissan', 'Hyundai', 'Honda', 'Mercedes-Benz',
#        'BMW', 'Ford', 'Tata', 'Jeep', 'Toyota', 'Audi', 'Mahindra',
#        'Renault', 'Chevrolet', 'Volkswagen', 'Datsun', 'Fiat',
#        'Land Rover', 'MG', 'Skoda', 'Isuzu', 'Mini', 'Volvo', 'Jaguar',
#        'Citroen', 'Mitsubishi', 'Mahindra Renault', 'Mahindra Ssangyong',
#        'Lexus', 'Porsche', 'Hindustan Motors', 'Opel'], dtype=object)

# %%
finaldf["oem"].value_counts()
# Out:
# oem
# Maruti                1812
# Hyundai               1343
# Honda                  738
# Tata                   338
# Mahindra               314
# Toyota                 280
# Renault                258
# Ford                   257
# Volkswagen             236
# Mercedes-Benz          220
# BMW                    163
# Kia                    141
# Audi                   139
# Skoda                  131
# Jeep                    93
# MG                      72
# Chevrolet               60
# Nissan                  58
# Datsun                  50
# Land Rover              40
# Volvo                   30
# Fiat                    25
# Jaguar                  25
# Mitsubishi              14
# Mini                    12
# Citroen                  7
# Porsche                  6
# Isuzu                    5
# Mahindra Renault         5
# Lexus                    5
# Mahindra Ssangyong       3
# Hindustan Motors         3
# Opel                     3
# Name: count, dtype: int64

# %%
finaldf.ft.unique()
# Out:
# array(['Petrol', 'Diesel', 'Electric', 'Cng', 'Lpg'], dtype=object)

# %%
finaldf.transmission.unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
finaldf.ownerNo.unique()
# Out:
# array([1, 2, 3, 4, 0, 5])

# %%
finaldf.modelYear.unique()
# Out:
# array([2022, 2015, 2021, 2016, 2010, 2018, 2019, 2020, 2017, 2014, 2013,
#        2008, 2011, 2012, 2007, 2009, 2023, 2002, 2004, 2006, 2003, 2005,
#        2001, 1999, 1998, 1985, 1995, 2000])

# %%
finaldf.City.unique()
# Out:
# array(['Chennai', 'Delhi', 'Jaipur', 'Kolkata', 'Bangalore'], dtype=object)

# %%
finaldf
# Out:
#           ft         bt        km transmission  ownerNo      oem  modelYear  \
# 0     Petrol        SUV    20,000    Automatic        1      Kia       2022
# 1     Petrol   Minivans    20,687       Manual        1   Maruti       2015
# 2     Petrol        SUV    30,000       Manual        1   Nissan       2021
# 3     Petrol  Hatchback    59,247       Manual        1  Hyundai       2015
# 4     Petrol  Hatchback    50,000       Manual        1    Honda       2015
# ...      ...        ...       ...          ...      ...      ...        ...
# 6881  Diesel        SUV  1,56,039       Manual        2   Toyota       2012
# 6882  Petrol      Sedan    56,000       Manual        2   Maruti       2008
# 6883  Petrol  Hatchback    42,000       Manual        2    Honda       2014
# 6884  Diesel  Hatchback    93,003       Manual        1  Hyundai       2018
# 6885  Petrol  Hatchback    36,000    Automatic        2  Hyundai       2017
#
#              price     Engine     Mileage       City
# ...

# %%
finaldf.km.isnull().sum()
# Out:
# np.int64(0)

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6886 entries, 0 to 6885
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ft            6886 non-null   object
#  1   bt            6886 non-null   object
#  2   km            6886 non-null   object
#  3   transmission  6886 non-null   object
#  4   ownerNo       6886 non-null   int64
#  5   oem           6886 non-null   object
#  6   modelYear     6886 non-null   int64
#  7   price         6886 non-null   object
#  8   Engine        6885 non-null   object
#  9   Mileage       6886 non-null   object
#  10  City          6886 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 591.9+ KB

# %%
finaldf=finaldf.dropna()

# %%
finaldf=finaldf.drop(0)
finaldf
# Out:
#           ft         bt        km transmission  ownerNo            oem  \
# 1     Petrol   Minivans    20,687       Manual        1         Maruti
# 2     Petrol        SUV    30,000       Manual        1         Nissan
# 3     Petrol  Hatchback    59,247       Manual        1        Hyundai
# 4     Petrol  Hatchback    50,000       Manual        1          Honda
# 5     Diesel      Sedan    20,000    Automatic        1  Mercedes-Benz
# ...      ...        ...       ...          ...      ...            ...
# 6881  Diesel        SUV  1,56,039       Manual        2         Toyota
# 6882  Petrol      Sedan    56,000       Manual        2         Maruti
# 6883  Petrol  Hatchback    42,000       Manual        2          Honda
# 6884  Diesel  Hatchback    93,003       Manual        1        Hyundai
# 6885  Petrol  Hatchback    36,000    Automatic        2        Hyundai
#
#       modelYear         price   Engine     Mileage       City
# ...

# %%
finaldf.modelYear.isnull().sum()
# Out:
# np.int64(0)

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6884 entries, 1 to 6885
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ft            6884 non-null   object
#  1   bt            6884 non-null   object
#  2   km            6884 non-null   object
#  3   transmission  6884 non-null   object
#  4   ownerNo       6884 non-null   int64
#  5   oem           6884 non-null   object
#  6   modelYear     6884 non-null   int64
#  7   price         6884 non-null   object
#  8   Engine        6884 non-null   object
#  9   Mileage       6884 non-null   object
#  10  City          6884 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 645.4+ KB

# %%
backup=finaldf

# %% [markdown]
# Checking duplicates

# %%
finaldf.duplicated().sum()
# Out:
# np.int64(105)

# %%
finaldf=finaldf.drop_duplicates()

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6779 entries, 1 to 6885
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ft            6779 non-null   object
#  1   bt            6779 non-null   object
#  2   km            6779 non-null   object
#  3   transmission  6779 non-null   object
#  4   ownerNo       6779 non-null   int64
#  5   oem           6779 non-null   object
#  6   modelYear     6779 non-null   int64
#  7   price         6779 non-null   object
#  8   Engine        6779 non-null   object
#  9   Mileage       6779 non-null   object
#  10  City          6779 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 635.5+ KB

# %%
finaldf=finaldf.reset_index()

# %%
finaldf
# Out:
#       index      ft         bt        km transmission  ownerNo            oem  \
# 0         1  Petrol   Minivans    20,687       Manual        1         Maruti
# 1         2  Petrol        SUV    30,000       Manual        1         Nissan
# 2         3  Petrol  Hatchback    59,247       Manual        1        Hyundai
# 3         4  Petrol  Hatchback    50,000       Manual        1          Honda
# 4         5  Diesel      Sedan    20,000    Automatic        1  Mercedes-Benz
# ...     ...     ...        ...       ...          ...      ...            ...
# 6774   6881  Diesel        SUV  1,56,039       Manual        2         Toyota
# 6775   6882  Petrol      Sedan    56,000       Manual        2         Maruti
# 6776   6883  Petrol  Hatchback    42,000       Manual        2          Honda
# 6777   6884  Diesel  Hatchback    93,003       Manual        1        Hyundai
# 6778   6885  Petrol  Hatchback    36,000    Automatic        2        Hyundai
#
# ...

# %%
finaldf['km'] = finaldf['km'].str.replace(',', '').astype(int)
finaldf
# Out:
#       index      ft         bt      km transmission  ownerNo            oem  \
# 0         1  Petrol   Minivans   20687       Manual        1         Maruti
# 1         2  Petrol        SUV   30000       Manual        1         Nissan
# 2         3  Petrol  Hatchback   59247       Manual        1        Hyundai
# 3         4  Petrol  Hatchback   50000       Manual        1          Honda
# 4         5  Diesel      Sedan   20000    Automatic        1  Mercedes-Benz
# ...     ...     ...        ...     ...          ...      ...            ...
# 6774   6881  Diesel        SUV  156039       Manual        2         Toyota
# 6775   6882  Petrol      Sedan   56000       Manual        2         Maruti
# 6776   6883  Petrol  Hatchback   42000       Manual        2          Honda
# 6777   6884  Diesel  Hatchback   93003       Manual        1        Hyundai
# 6778   6885  Petrol  Hatchback   36000    Automatic        2        Hyundai
#
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6779 entries, 0 to 6778
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         6779 non-null   int64
#  1   ft            6779 non-null   object
#  2   bt            6779 non-null   object
#  3   km            6779 non-null   int64
#  4   transmission  6779 non-null   object
#  5   ownerNo       6779 non-null   int64
#  6   oem           6779 non-null   object
#  7   modelYear     6779 non-null   int64
#  8   price         6779 non-null   object
#  9   Engine        6779 non-null   object
#  10  Mileage       6779 non-null   object
#  11  City          6779 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 635.7+ KB

# %%
finaldf=finaldf.reset_index()
finaldf
# Out:
#       level_0  index      ft         bt      km transmission  ownerNo  \
# 0           0      1  Petrol   Minivans   20687       Manual        1
# 1           1      2  Petrol        SUV   30000       Manual        1
# 2           2      3  Petrol  Hatchback   59247       Manual        1
# 3           3      4  Petrol  Hatchback   50000       Manual        1
# 4           4      5  Diesel      Sedan   20000    Automatic        1
# ...       ...    ...     ...        ...     ...          ...      ...
# 6774     6774   6881  Diesel        SUV  156039       Manual        2
# 6775     6775   6882  Petrol      Sedan   56000       Manual        2
# 6776     6776   6883  Petrol  Hatchback   42000       Manual        2
# 6777     6777   6884  Diesel  Hatchback   93003       Manual        1
# 6778     6778   6885  Petrol  Hatchback   36000    Automatic        2
#
#                 oem  modelYear         price   Engine     Mileage       City
# ...

# %%
finaldf.price=finaldf.price.str.replace('?','')
finaldf
# Out:
#       level_0  index      ft         bt      km transmission  ownerNo  \
# 0           0      1  Petrol   Minivans   20687       Manual        1
# 1           1      2  Petrol        SUV   30000       Manual        1
# 2           2      3  Petrol  Hatchback   59247       Manual        1
# 3           3      4  Petrol  Hatchback   50000       Manual        1
# 4           4      5  Diesel      Sedan   20000    Automatic        1
# ...       ...    ...     ...        ...     ...          ...      ...
# 6774     6774   6881  Diesel        SUV  156039       Manual        2
# 6775     6775   6882  Petrol      Sedan   56000       Manual        2
# 6776     6776   6883  Petrol  Hatchback   42000       Manual        2
# 6777     6777   6884  Diesel  Hatchback   93003       Manual        1
# 6778     6778   6885  Petrol  Hatchback   36000    Automatic        2
#
#                 oem  modelYear        price   Engine     Mileage       City
# ...

# %%
finaldf.price=finaldf.price.str.replace(' Lakh','')
finaldf
# Out:
#       level_0  index      ft         bt      km transmission  ownerNo  \
# 0           0      1  Petrol   Minivans   20687       Manual        1
# 1           1      2  Petrol        SUV   30000       Manual        1
# 2           2      3  Petrol  Hatchback   59247       Manual        1
# 3           3      4  Petrol  Hatchback   50000       Manual        1
# 4           4      5  Diesel      Sedan   20000    Automatic        1
# ...       ...    ...     ...        ...     ...          ...      ...
# 6774     6774   6881  Diesel        SUV  156039       Manual        2
# 6775     6775   6882  Petrol      Sedan   56000       Manual        2
# 6776     6776   6883  Petrol  Hatchback   42000       Manual        2
# 6777     6777   6884  Diesel  Hatchback   93003       Manual        1
# 6778     6778   6885  Petrol  Hatchback   36000    Automatic        2
#
#                 oem  modelYear   price   Engine     Mileage       City
# ...

# %%
finaldf.Mileage=finaldf.Mileage.str.replace('kmpl','')
finaldf
# Out:
#       level_0  index      ft         bt      km transmission  ownerNo  \
# 0           0      1  Petrol   Minivans   20687       Manual        1
# 1           1      2  Petrol        SUV   30000       Manual        1
# 2           2      3  Petrol  Hatchback   59247       Manual        1
# 3           3      4  Petrol  Hatchback   50000       Manual        1
# 4           4      5  Diesel      Sedan   20000    Automatic        1
# ...       ...    ...     ...        ...     ...          ...      ...
# 6774     6774   6881  Diesel        SUV  156039       Manual        2
# 6775     6775   6882  Petrol      Sedan   56000       Manual        2
# 6776     6776   6883  Petrol  Hatchback   42000       Manual        2
# 6777     6777   6884  Diesel  Hatchback   93003       Manual        1
# 6778     6778   6885  Petrol  Hatchback   36000    Automatic        2
#
#                 oem  modelYear   price   Engine Mileage       City
# ...

# %%
finaldf.Engine=finaldf.Engine.str.replace(' CC','')
finaldf
# Out:
#       level_0  index      ft         bt      km transmission  ownerNo  \
# 0           0      1  Petrol   Minivans   20687       Manual        1
# 1           1      2  Petrol        SUV   30000       Manual        1
# 2           2      3  Petrol  Hatchback   59247       Manual        1
# 3           3      4  Petrol  Hatchback   50000       Manual        1
# 4           4      5  Diesel      Sedan   20000    Automatic        1
# ...       ...    ...     ...        ...     ...          ...      ...
# 6774     6774   6881  Diesel        SUV  156039       Manual        2
# 6775     6775   6882  Petrol      Sedan   56000       Manual        2
# 6776     6776   6883  Petrol  Hatchback   42000       Manual        2
# 6777     6777   6884  Diesel  Hatchback   93003       Manual        1
# 6778     6778   6885  Petrol  Hatchback   36000    Automatic        2
#
#                 oem  modelYear   price Engine Mileage       City
# ...

# %%
finaldf['Price'] = finaldf['Price'].str.replace(',', '').astype(float)
finaldf

# %%
finaldf=finaldf.drop(["level_0","index"],axis=1)
finaldf
# Out:
#           ft         bt      km transmission  ownerNo            oem  \
# 0     Petrol   Minivans   20687       Manual        1         Maruti
# 1     Petrol        SUV   30000       Manual        1         Nissan
# 2     Petrol  Hatchback   59247       Manual        1        Hyundai
# 3     Petrol  Hatchback   50000       Manual        1          Honda
# 4     Diesel      Sedan   20000    Automatic        1  Mercedes-Benz
# ...      ...        ...     ...          ...      ...            ...
# 6774  Diesel        SUV  156039       Manual        2         Toyota
# 6775  Petrol      Sedan   56000       Manual        2         Maruti
# 6776  Petrol  Hatchback   42000       Manual        2          Honda
# 6777  Diesel  Hatchback   93003       Manual        1        Hyundai
# 6778  Petrol  Hatchback   36000    Automatic        2        Hyundai
#
#       modelYear   price Engine Mileage       City
# 0          2015    4.15   1196  15.37     Chennai
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6779 entries, 0 to 6778
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ft            6779 non-null   object
#  1   bt            6779 non-null   object
#  2   km            6779 non-null   int64
#  3   transmission  6779 non-null   object
#  4   ownerNo       6779 non-null   int64
#  5   oem           6779 non-null   object
#  6   modelYear     6779 non-null   int64
#  7   price         6779 non-null   object
#  8   Engine        6779 non-null   object
#  9   Mileage       6779 non-null   object
#  10  City          6779 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 582.7+ KB

# %%
#finaldf.to_csv("C:/Users/hp/Desktop/Cardekho_Project/finaldf_data2.csv",sep=',',encoding='utf-8')

# %%
finaldf=pd.read_csv("C:/Users/hp/Desktop/Cardekho_Project/finaldf_data2.csv",encoding="ISO-8859-1")

# %%
finaldf
# Out:
#       Unnamed: 0      ft         bt        km transmission  ownerNo  \
# 0            0.0  Petrol   Minivans   20687.0       Manual      1.0
# 1            1.0  Petrol        SUV   30000.0       Manual      1.0
# 2            2.0  Petrol  Hatchback   59247.0       Manual      1.0
# 3            3.0  Petrol  Hatchback   50000.0       Manual      1.0
# 4            4.0  Diesel      Sedan   20000.0    Automatic      1.0
# ...          ...     ...        ...       ...          ...      ...
# 6774      6774.0  Diesel        SUV  156039.0       Manual      2.0
# 6775      6775.0  Petrol      Sedan   56000.0       Manual      2.0
# 6776      6776.0  Petrol  Hatchback   42000.0       Manual      2.0
# 6777      6777.0  Diesel  Hatchback   93003.0       Manual      1.0
# 6778      6778.0  Petrol  Hatchback   36000.0    Automatic      2.0
#
#                 oem  modelYear  price  Engine Mileage       City
# 0            Maruti     2015.0   4.15  1196.0   15.37    Chennai
# ...

# %%
finaldf=finaldf.dropna()
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6540 entries, 0 to 6778
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    6540 non-null   float64
#  1   ft            6540 non-null   object
#  2   bt            6540 non-null   object
#  3   km            6540 non-null   float64
#  4   transmission  6540 non-null   object
#  5   ownerNo       6540 non-null   float64
#  6   oem           6540 non-null   object
#  7   modelYear     6540 non-null   float64
#  8   price         6540 non-null   object
#  9   Engine        6540 non-null   float64
#  10  Mileage       6540 non-null   object
#  11  City          6540 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 664.2+ KB

# %%
finaldf=finaldf.drop(["Unnamed: 0"],axis=1)
finaldf
# Out:
#           ft         bt        km transmission  ownerNo            oem  \
# 0     Petrol   Minivans   20687.0       Manual      1.0         Maruti
# 1     Petrol        SUV   30000.0       Manual      1.0         Nissan
# 2     Petrol  Hatchback   59247.0       Manual      1.0        Hyundai
# 3     Petrol  Hatchback   50000.0       Manual      1.0          Honda
# 4     Diesel      Sedan   20000.0    Automatic      1.0  Mercedes-Benz
# ...      ...        ...       ...          ...      ...            ...
# 6774  Diesel        SUV  156039.0       Manual      2.0         Toyota
# 6775  Petrol      Sedan   56000.0       Manual      2.0         Maruti
# 6776  Petrol  Hatchback   42000.0       Manual      2.0          Honda
# 6777  Diesel  Hatchback   93003.0       Manual      1.0        Hyundai
# 6778  Petrol  Hatchback   36000.0    Automatic      2.0        Hyundai
#
#       modelYear  price  Engine Mileage       City
# 0        2015.0   4.15  1196.0   15.37    Chennai
# ...

# %% [markdown]
# Changing datatypes of number columns

# %%
finaldf.km=finaldf.km.astype(int)

# %%
finaldf.ownerNo=finaldf.ownerNo.astype(int)
finaldf.Engine=finaldf.Engine.astype(int)

# %%
finaldf.modelYear=finaldf.modelYear.astype(int)

# %%
finaldf=finaldf.reset_index()

# %%
finaldf
# Out:
#       index      ft         bt      km transmission  ownerNo            oem  \
# 0         0  Petrol   Minivans   20687       Manual        1         Maruti
# 1         1  Petrol        SUV   30000       Manual        1         Nissan
# 2         2  Petrol  Hatchback   59247       Manual        1        Hyundai
# 3         3  Petrol  Hatchback   50000       Manual        1          Honda
# 4         4  Diesel      Sedan   20000    Automatic        1  Mercedes-Benz
# ...     ...     ...        ...     ...          ...      ...            ...
# 6535   6774  Diesel        SUV  156039       Manual        2         Toyota
# 6536   6775  Petrol      Sedan   56000       Manual        2         Maruti
# 6537   6776  Petrol  Hatchback   42000       Manual        2          Honda
# 6538   6777  Diesel  Hatchback   93003       Manual        1        Hyundai
# 6539   6778  Petrol  Hatchback   36000    Automatic        2        Hyundai
#
#       modelYear  price  Engine Mileage       City
# ...

# %%
finaldf=finaldf.drop(["index"],axis=1)
finaldf
# Out:
#           ft         bt      km transmission  ownerNo            oem  \
# 0     Petrol   Minivans   20687       Manual        1         Maruti
# 1     Petrol        SUV   30000       Manual        1         Nissan
# 2     Petrol  Hatchback   59247       Manual        1        Hyundai
# 3     Petrol  Hatchback   50000       Manual        1          Honda
# 4     Diesel      Sedan   20000    Automatic        1  Mercedes-Benz
# ...      ...        ...     ...          ...      ...            ...
# 6535  Diesel        SUV  156039       Manual        2         Toyota
# 6536  Petrol      Sedan   56000       Manual        2         Maruti
# 6537  Petrol  Hatchback   42000       Manual        2          Honda
# 6538  Diesel  Hatchback   93003       Manual        1        Hyundai
# 6539  Petrol  Hatchback   36000    Automatic        2        Hyundai
#
#       modelYear  price  Engine Mileage       City
# 0          2015   4.15    1196   15.37    Chennai
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6540 entries, 0 to 6539
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ft            6540 non-null   object
#  1   bt            6540 non-null   object
#  2   km            6540 non-null   int64
#  3   transmission  6540 non-null   object
#  4   ownerNo       6540 non-null   int64
#  5   oem           6540 non-null   object
#  6   modelYear     6540 non-null   int64
#  7   price         6540 non-null   object
#  8   Engine        6540 non-null   int64
#  9   Mileage       6540 non-null   object
#  10  City          6540 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 562.2+ KB

# %% [markdown]
# renaming the columns meaningful

# %%
finaldf.rename(columns={'ft':'FuelType'},inplace=True)
finaldf.rename(columns={'bt':'BodyType'},inplace=True)
finaldf.rename(columns={'km':'KmsDriven'},inplace=True)
finaldf.rename(columns={'transmission':'Transmission'},inplace=True)
finaldf.rename(columns={'ownerNo':'OwnerNo'},inplace=True)
finaldf.rename(columns={'oem':'ModelBrand'},inplace=True)
finaldf.rename(columns={'modelYear':'ModelYear'},inplace=True)
finaldf.rename(columns={'price':'Price'},inplace=True)
finaldf
# Out:
#      FuelType   BodyType  KmsDriven Transmission  OwnerNo     ModelBrand  \
# 0      Petrol   Minivans      20687       Manual        1         Maruti
# 1      Petrol        SUV      30000       Manual        1         Nissan
# 2      Petrol  Hatchback      59247       Manual        1        Hyundai
# 3      Petrol  Hatchback      50000       Manual        1          Honda
# 4      Diesel      Sedan      20000    Automatic        1  Mercedes-Benz
# ...       ...        ...        ...          ...      ...            ...
# 6535   Diesel        SUV     156039       Manual        2         Toyota
# 6536   Petrol      Sedan      56000       Manual        2         Maruti
# 6537   Petrol  Hatchback      42000       Manual        2          Honda
# 6538   Diesel  Hatchback      93003       Manual        1        Hyundai
# 6539   Petrol  Hatchback      36000    Automatic        2        Hyundai
#
#       ModelYear  Price  Engine Mileage       City
# ...

# %%
finaldf.describe()
# Out:
#           KmsDriven      OwnerNo    ModelYear       Engine      Mileage
# count  6.510000e+03  6510.000000  6510.000000  6510.000000  6510.000000
# mean   5.838610e+04     1.371121  2016.393702  1428.726728    19.099343
# std    8.066870e+04     0.659773     3.792229   476.077002     3.910734
# min    0.000000e+00     0.000000  1985.000000     6.000000     7.080000
# 25%    3.000000e+04     1.000000  2014.000000  1197.000000    17.000000
# 50%    5.200000e+04     1.000000  2017.000000  1248.000000    18.900000
# 75%    7.800000e+04     2.000000  2019.000000  1498.000000    21.400000
# max    5.500000e+06     5.000000  2023.000000  5000.000000   140.000000

# %% [markdown]
# Encoding the categorical columns to numeric

# %%
pip install -U scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.0 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/11.0 MB 1.2 MB/s eta 0:00:09
#     --------------------------------------- 0.2/11.0 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/11.0 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/11.0 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/11.0 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.6/11.0 MB 1.6 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/11.0 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/11.0 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/11.0 MB 1.6 MB/s eta 0:00:07
# ...

# %%
import numpy as np 

from sklearn.preprocessing import LabelEncoder

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
finaldf["City"].unique()
# Out:
# array(['Chennai', 'Delhi', 'Jaipur', 'Kolkata', 'Bangalore'], dtype=object)

# %%
finaldf["City"]=le.fit_transform(finaldf["City"])
finaldf["City"].unique()
# Out:
# array([1, 2, 3, 4, 0])

# %%
finaldf
# Out:
#      FuelType   BodyType  KmsDriven Transmission  OwnerNo     ModelBrand  \
# 0      Petrol   Minivans      20687       Manual        1         Maruti
# 1      Petrol        SUV      30000       Manual        1         Nissan
# 2      Petrol  Hatchback      59247       Manual        1        Hyundai
# 3      Petrol  Hatchback      50000       Manual        1          Honda
# 4      Diesel      Sedan      20000    Automatic        1  Mercedes-Benz
# ...       ...        ...        ...          ...      ...            ...
# 6535   Diesel        SUV     156039       Manual        2         Toyota
# 6536   Petrol      Sedan      56000       Manual        2         Maruti
# 6537   Petrol  Hatchback      42000       Manual        2          Honda
# 6538   Diesel  Hatchback      93003       Manual        1        Hyundai
# 6539   Petrol  Hatchback      36000    Automatic        2        Hyundai
#
#       ModelYear  Price  Engine Mileage  City
# 0          2015   4.15    1196   15.37     1
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6540 entries, 0 to 6539
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FuelType      6540 non-null   object
#  1   BodyType      6540 non-null   object
#  2   KmsDriven     6540 non-null   int64
#  3   Transmission  6540 non-null   object
#  4   OwnerNo       6540 non-null   int64
#  5   ModelBrand    6540 non-null   object
#  6   ModelYear     6540 non-null   int64
#  7   Price         6540 non-null   object
#  8   Engine        6540 non-null   int64
#  9   Mileage       6540 non-null   object
#  10  City          6540 non-null   int64
# dtypes: int64(5), object(6)
# memory usage: 562.2+ KB

# %%
finaldf.FuelType.unique()
# Out:
# array(['Petrol', 'Diesel', 'Cng', 'Lpg', 'Electric'], dtype=object)

# %%
finaldf["FuelType"]=le.fit_transform(finaldf["FuelType"])
finaldf["FuelType"].unique()
# Out:
# array([4, 1, 0, 3, 2])

# %%
finaldf.BodyType.unique()
# Out:
# array(['Minivans', 'SUV', 'Hatchback', 'Sedan', 'MUV', 'Hybrids', 'Coupe',
#        'Convertibles', 'Wagon', 'Pickup Trucks'], dtype=object)

# %%
finaldf["BodyType"]=le.fit_transform(finaldf["BodyType"])
finaldf["BodyType"].unique()
# Out:
# array([5, 7, 2, 8, 4, 3, 1, 0, 9, 6])

# %%
finaldf["Transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
finaldf["Transmission"]=le.fit_transform(finaldf["Transmission"])
finaldf["Transmission"].unique()
# Out:
# array([1, 0])

# %%
finaldf["ModelBrand"].unique()
# Out:
# array(['Maruti', 'Nissan', 'Hyundai', 'Honda', 'Mercedes-Benz', 'BMW',
#        'Ford', 'Tata', 'Jeep', 'Audi', 'Toyota', 'Mahindra', 'Renault',
#        'Chevrolet', 'Volkswagen', 'Datsun', 'Kia', 'Fiat', 'Land Rover',
#        'MG', 'Skoda', 'Isuzu', 'Mini', 'Volvo', 'Jaguar', 'Citroen',
#        'Mitsubishi', 'Mahindra Renault', 'Mahindra Ssangyong', 'Lexus',
#        'Porsche', 'Hindustan Motors', 'Opel'], dtype=object)

# %%
finaldf["ModelBrand"]=le.fit_transform(finaldf["ModelBrand"])
finaldf["ModelBrand"].unique()
# Out:
# array([20, 24,  9,  8, 21,  1,  6, 29, 12,  0, 30, 17, 27,  2, 31,  4, 13,
#         5, 14, 16, 28, 10, 22, 32, 11,  3, 23, 18, 19, 15, 26,  7, 25])

# %%
finaldf
# Out:
#       FuelType  BodyType  KmsDriven  Transmission  OwnerNo  ModelBrand  \
# 0            4         5      20687             1        1          20
# 1            4         7      30000             1        1          24
# 2            4         2      59247             1        1           9
# 3            4         2      50000             1        1           8
# 4            1         8      20000             0        1          21
# ...        ...       ...        ...           ...      ...         ...
# 6535         1         7     156039             1        2          30
# 6536         4         8      56000             1        2          20
# 6537         4         2      42000             1        2           8
# 6538         1         2      93003             1        1           9
# 6539         4         2      36000             0        2           9
#
#       ModelYear  Price  Engine Mileage  City
# 0          2015   4.15    1196   15.37     1
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6540 entries, 0 to 6539
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FuelType      6540 non-null   int64
#  1   BodyType      6540 non-null   int64
#  2   KmsDriven     6540 non-null   int64
#  3   Transmission  6540 non-null   int64
#  4   OwnerNo       6540 non-null   int64
#  5   ModelBrand    6540 non-null   int64
#  6   ModelYear     6540 non-null   int64
#  7   Price         6540 non-null   object
#  8   Engine        6540 non-null   int64
#  9   Mileage       6540 non-null   object
#  10  City          6540 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 562.2+ KB

# %%
finaldf["Price"].max()
# Out:
# '99,703'

# %%
finaldf["Price"].min()
# Out:
# '1'

# %%
finaldf["Price"].str.contains(',').sum()
# Out:
# np.int64(90)

# %%
finaldf['Price'] = finaldf['Price'].str.replace(',', '').astype(float)
finaldf
# Out:
#       FuelType  BodyType  KmsDriven  Transmission  OwnerNo  ModelBrand  \
# 0            4         5      20687             1        1          20
# 1            4         7      30000             1        1          24
# 2            4         2      59247             1        1           9
# 3            4         2      50000             1        1           8
# 4            1         8      20000             0        1          21
# ...        ...       ...        ...           ...      ...         ...
# 6535         1         7     156039             1        2          30
# 6536         4         8      56000             1        2          20
# 6537         4         2      42000             1        2           8
# 6538         1         2      93003             1        1           9
# 6539         4         2      36000             0        2           9
#
#       ModelYear  Price  Engine Mileage  City
# 0          2015   4.15    1196   15.37     1
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6540 entries, 0 to 6539
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FuelType      6540 non-null   int64
#  1   BodyType      6540 non-null   int64
#  2   KmsDriven     6540 non-null   int64
#  3   Transmission  6540 non-null   int64
#  4   OwnerNo       6540 non-null   int64
#  5   ModelBrand    6540 non-null   int64
#  6   ModelYear     6540 non-null   int64
#  7   Price         6540 non-null   float64
#  8   Engine        6540 non-null   int64
#  9   Mileage       6540 non-null   object
#  10  City          6540 non-null   int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 562.2+ KB

# %%
finaldf.loc[finaldf["Price"]>=28000,'Price']/=100000 #search and filter price value more than 28000 and converting it to lakhs

# %%
finaldf["Price"].max()
# Out:
# np.float64(245.0)

# %%
finaldf.Price.min()
# Out:
# np.float64(0.28)

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6540 entries, 0 to 6539
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FuelType      6540 non-null   int64
#  1   BodyType      6540 non-null   int64
#  2   KmsDriven     6540 non-null   int64
#  3   Transmission  6540 non-null   int64
#  4   OwnerNo       6540 non-null   int64
#  5   ModelBrand    6540 non-null   int64
#  6   ModelYear     6540 non-null   int64
#  7   Price         6540 non-null   float64
#  8   Engine        6540 non-null   int64
#  9   Mileage       6540 non-null   object
#  10  City          6540 non-null   int64
# dtypes: float64(1), int64(9), object(1)
# memory usage: 562.2+ KB

# %%
for i in finaldf.Mileage:
    if str(i).endswith('km/kg'):
        i = i[:-6]
        i = float(i)*1.40

# %%
finaldf.loc[finaldf["Mileage"].str.contains("km/kg"),'Mileage']*1
# Out:
# 951     26.49 km/kg
# 1212    26.49 km/kg
# 1365       28 km/kg
# 1423    30.48 km/kg
# 1439    26.08 km/kg
# 1522    26.49 km/kg
# 1690    26.49 km/kg
# 1721     35.6 km/kg
# 1915     35.6 km/kg
# 1997    31.59 km/kg
# 2033    31.59 km/kg
# 2169    31.12 km/kg
# 2235     18.9 km/kg
# 2342    26.49 km/kg
# 2393    26.11 km/kg
# 2520    26.08 km/kg
# 2568    26.49 km/kg
# 2622    30.48 km/kg
# 2660     26.6 km/kg
# 2679    30.48 km/kg
# 3117    26.49 km/kg
# 3194    31.59 km/kg
# 3195    20.88 km/kg
# 3318     35.6 km/kg
# 3370    20.88 km/kg
# 3872     35.6 km/kg
# 3944    26.49 km/kg
# 4107    30.48 km/kg
# 5871    20.88 km/kg
# 6451    31.59 km/kg
# Name: Mileage, dtype: object

# %%
finaldf.Mileage=finaldf.Mileage.str.replace(' km/kg','')
finaldf
# Out:
#       FuelType  BodyType  KmsDriven  Transmission  OwnerNo  ModelBrand  \
# 0            4         5      20687             1        1          20
# 1            4         7      30000             1        1          24
# 2            4         2      59247             1        1           9
# 3            4         2      50000             1        1           8
# 4            1         8      20000             0        1          21
# ...        ...       ...        ...           ...      ...         ...
# 6535         1         7     156039             1        2          30
# 6536         4         8      56000             1        2          20
# 6537         4         2      42000             1        2           8
# 6538         1         2      93003             1        1           9
# 6539         4         2      36000             0        2           9
#
#       ModelYear  Price  Engine Mileage  City
# 0          2015   4.15    1196   15.37     1
# ...

# %%
finaldf.loc[finaldf["Mileage"].str.contains("km/kg"),'Mileage']*1
# Out:
# Series([], Name: Mileage, dtype: object)

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6540 entries, 0 to 6539
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FuelType      6540 non-null   int64
#  1   BodyType      6540 non-null   int64
#  2   KmsDriven     6540 non-null   int64
#  3   Transmission  6540 non-null   int64
#  4   OwnerNo       6540 non-null   int64
#  5   ModelBrand    6540 non-null   int64
#  6   ModelYear     6540 non-null   int64
#  7   Price         6540 non-null   float64
#  8   Engine        6540 non-null   int64
#  9   Mileage       6540 non-null   float64
#  10  City          6540 non-null   int64
# dtypes: float64(2), int64(9)
# memory usage: 562.2 KB

# %%
finaldf.Mileage=finaldf.Mileage.astype(float)

# %%
finaldf.to_csv("C:/Users/hp/Desktop/Cardekho_Project/finaldf_transformeddata.csv",sep=',',encoding='utf-8')

# %%
finaldf
# Out:
#       FuelType  BodyType  KmsDriven  Transmission  OwnerNo  ModelBrand  \
# 0            4         5      20687             1        1          20
# 1            4         7      30000             1        1          24
# 2            4         2      59247             1        1           9
# 3            4         2      50000             1        1           8
# 4            1         8      20000             0        1          21
# ...        ...       ...        ...           ...      ...         ...
# 6535         1         7     156039             1        2          30
# 6536         4         8      56000             1        2          20
# 6537         4         2      42000             1        2           8
# 6538         1         2      93003             1        1           9
# 6539         4         2      36000             0        2           9
#
#       ModelYear  Price  Engine  Mileage  City
# 0          2015   4.15    1196    15.37     1
# ...

# %% [markdown]
# Correlation

# %%
my_matrix=finaldf.corr().round(2)

# %%
my_matrix
# Out:
#               FuelType  BodyType  KmsDriven  Transmission  OwnerNo  \
# FuelType          1.00     -0.29      -0.16          0.08    -0.07
# BodyType         -0.29      1.00       0.04         -0.25    -0.01
# KmsDriven        -0.16      0.04       1.00          0.05     0.11
# Transmission      0.08     -0.25       0.05          1.00     0.02
# OwnerNo          -0.07     -0.01       0.11          0.02     1.00
# ModelBrand       -0.00     -0.11       0.01          0.08    -0.05
# ModelYear         0.07      0.08      -0.22         -0.18    -0.40
# Price            -0.21      0.30      -0.06         -0.47    -0.12
# Engine           -0.49      0.49       0.09         -0.38     0.07
# Mileage          -0.10     -0.34      -0.02          0.28    -0.09
# City             -0.01      0.01      -0.04          0.09    -0.09
#
#               ModelBrand  ModelYear  Price  Engine  Mileage  City
# FuelType           -0.00       0.07  -0.21   -0.49    -0.10 -0.01
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.heatmap(my_matrix,cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt

# %%
finaldf.FuelType.value_counts()
# Out:
# FuelType
# 4    4437
# 1    2014
# 0      79
# 3       9
# 2       1
# Name: count, dtype: int64

# %%
#plotting all the three numerical columns
plt.figure(figsize=(16,4))

plt.subplot(1,3,1)
sns.scatterplot(x=finaldf["ModelYear"],y=finaldf["Price"]);
plt.title("Year vs Price")

plt.subplot(1,3,2)
sns.scatterplot(x=finaldf["Engine"],y=finaldf["Price"]);
plt.title("EngineV vs Price")

plt.subplot(1,3,3)
sns.scatterplot(x=finaldf["Mileage"],y=finaldf["Price"]);
plt.title("Mileage vs Price")
# Out:
# Text(0.5, 1.0, 'Mileage vs Price')

# %% [markdown]
# Outliers removal

# %%
sns.boxplot(finaldf["Price"])
# Out:
# <Axes: ylabel='Price'>

# %%
sorted(finaldf['Price'],reverse=True)
# Out:
# [245.0,
#  210.0,
#  159.0,
#  155.0,
#  150.0,
#  132.0,
#  132.0,
#  130.0,
#  118.0,
#  110.0,
#  110.0,
#  105.0,
#  103.0,
#  96.0,
#  95.0,
#  93.5,
#  91.0,
#  90.0,
#  89.0,
#  88.0,
#  87.65,
#  82.0,
#  82.0,
#  79.0,
#  79.0,
#  77.5,
#  77.0,
#  76.0,
#  75.0,
#  74.0,
#  72.9,
#  72.0,
#  71.25,
#  70.0,
#  70.0,
#  69.5,
#  69.0,
#  68.0,
#  68.0,
#  67.95,
#  66.75,
#  66.0,
#  66.0,
#  66.0,
#  65.0,
#  64.75,
#  64.75,
#  64.0,
#  63.5,
#  63.0,
#  63.0,
#  62.5,
#  62.5,
#  62.0,
#  62.0,
#  62.0,
#  61.5,
#  61.0,
#  60.75,
#  60.5,
#  60.0,
#  60.0,
#  60.0,
#  59.9,
#  58.95,
#  58.9,
#  58.9,
#  58.9,
#  58.5,
#  57.99,
#  57.9,
#  57.75,
#  57.5,
#  57.5,
#  57.5,
#  57.0,
#  57.0,
#  57.0,
#  56.0,
#  56.0,
#  56.0,
#  56.0,
#  56.0,
#  55.9,
#  55.5,
#  55.41,
#  55.0,
#  55.0,
#  55.0,
#  54.95,
#  54.9,
#  54.0,
#  54.0,
#  53.0,
#  53.0,
#  53.0,
#  53.0,
#  52.75,
#  52.6,
#  52.5,
#  52.5,
#  52.45,
#  52.4,
#  52.0,
#  52.0,
#  52.0,
#  52.0,
#  51.9,
# ...

# %%
finaldf=finaldf[~(finaldf['Price']>=210.0)]

# %%
finaldf
# Out:
#       FuelType  BodyType  KmsDriven  Transmission  OwnerNo  ModelBrand  \
# 0            4         5      20687             1        1          20
# 1            4         7      30000             1        1          24
# 2            4         2      59247             1        1           9
# 3            4         2      50000             1        1           8
# 4            1         8      20000             0        1          21
# ...        ...       ...        ...           ...      ...         ...
# 6535         1         7     156039             1        2          30
# 6536         4         8      56000             1        2          20
# 6537         4         2      42000             1        2           8
# 6538         1         2      93003             1        1           9
# 6539         4         2      36000             0        2           9
#
#       ModelYear  Price  Engine  Mileage  City
# 0          2015   4.15    1196    15.37     1
# ...

# %%
sorted(finaldf['Price'],reverse=True) # we have removed the outlier
# Out:
# [159.0,
#  155.0,
#  150.0,
#  132.0,
#  132.0,
#  130.0,
#  118.0,
#  110.0,
#  110.0,
#  105.0,
#  103.0,
#  96.0,
#  95.0,
#  93.5,
#  91.0,
#  90.0,
#  89.0,
#  88.0,
#  87.65,
#  82.0,
#  82.0,
#  79.0,
#  79.0,
#  77.5,
#  77.0,
#  76.0,
#  75.0,
#  74.0,
#  72.9,
#  72.0,
#  71.25,
#  70.0,
#  70.0,
#  69.5,
#  69.0,
#  68.0,
#  68.0,
#  67.95,
#  66.75,
#  66.0,
#  66.0,
#  66.0,
#  65.0,
#  64.75,
#  64.75,
#  64.0,
#  63.5,
#  63.0,
#  63.0,
#  62.5,
#  62.5,
#  62.0,
#  62.0,
#  62.0,
#  61.5,
#  61.0,
#  60.75,
#  60.5,
#  60.0,
#  60.0,
#  60.0,
#  59.9,
#  58.95,
#  58.9,
#  58.9,
#  58.9,
#  58.5,
#  57.99,
#  57.9,
#  57.75,
#  57.5,
#  57.5,
#  57.5,
#  57.0,
#  57.0,
#  57.0,
#  56.0,
#  56.0,
#  56.0,
#  56.0,
#  56.0,
#  55.9,
#  55.5,
#  55.41,
#  55.0,
#  55.0,
#  55.0,
#  54.95,
#  54.9,
#  54.0,
#  54.0,
#  53.0,
#  53.0,
#  53.0,
#  53.0,
#  52.75,
#  52.6,
#  52.5,
#  52.5,
#  52.45,
#  52.4,
#  52.0,
#  52.0,
#  52.0,
#  52.0,
#  51.9,
#  51.75,
#  51.5,
# ...

# %%
sns.boxplot(finaldf["KmsDriven"])
# Out:
# <Axes: ylabel='KmsDriven'>

# %%
finaldf=finaldf[~(finaldf['KmsDriven']>=2000022)]

# %%
finaldf
# Out:
#       FuelType  BodyType  KmsDriven  Transmission  OwnerNo  ModelBrand  \
# 0            4         5      20687             1        1          20
# 1            4         7      30000             1        1          24
# 2            4         2      59247             1        1           9
# 3            4         2      50000             1        1           8
# 4            1         8      20000             0        1          21
# ...        ...       ...        ...           ...      ...         ...
# 6535         1         7     156039             1        2          30
# 6536         4         8      56000             1        2          20
# 6537         4         2      42000             1        2           8
# 6538         1         2      93003             1        1           9
# 6539         4         2      36000             0        2           9
#
#       ModelYear  Price  Engine  Mileage  City
# 0          2015   4.15    1196    15.37     1
# ...

# %%
sns.boxplot(finaldf["KmsDriven"])
# Out:
# <Axes: ylabel='KmsDriven'>

# %%
finaldf=finaldf[~(finaldf['KmsDriven']>=800000)]

# %%
sns.boxplot(finaldf["KmsDriven"])
# Out:
# <Axes: ylabel='KmsDriven'>

# %%
finaldf=finaldf[~(finaldf['Mileage']>=140)]

# %%
sns.boxplot(finaldf["Mileage"])
# Out:
# <Axes: ylabel='Mileage'>

# %% [markdown]
# Store Feature Matrix in X and Target in Y

# %%
X=finaldf.drop(["Price"],axis=1)
Y=finaldf["Price"]

# %%
X
# Out:
#       FuelType  BodyType  KmsDriven  Transmission  OwnerNo  ModelBrand  \
# 0            4         5      20687             1        1          20
# 1            4         7      30000             1        1          24
# 2            4         2      59247             1        1           9
# 3            4         2      50000             1        1           8
# 4            1         8      20000             0        1          21
# ...        ...       ...        ...           ...      ...         ...
# 6505         1         7     156039             1        2          30
# 6506         4         8      56000             1        2          20
# 6507         4         2      42000             1        2           8
# 6508         1         2      93003             1        1           9
# 6509         4         2      36000             0        2           9
#
#       ModelYear  Mileage  City  Engine
# 0          2015    15.37     1    1196
# ...

# %%
Y
# Out:
# 0       15.37
# 1       20.00
# 2       19.81
# 3       18.70
# 4       13.00
#         ...
# 6505    12.55
# 6506    15.00
# 6507    19.40
# 6508    22.54
# 6509    18.90
# Name: Price, Length: 6509, dtype: float64

# %% [markdown]
# Splitting the data set into Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=42)

# %% [markdown]
# Import the models

# %%
pip install xgboost
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn import metrics

# %%
lr= LinearRegression()
lr.fit(X_train,Y_train)

las= Lasso()
las.fit(X_train,Y_train)

rf= RandomForestRegressor()
rf.fit(X_train,Y_train)

xgb= GradientBoostingRegressor()
xgb.fit(X_train,Y_train)

xg= XGBRegressor()
xg.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
#prediction on test data
y_pred1=lr.predict(X_test)
y_pred2=las.predict(X_test)
y_pred3=rf.predict(X_test)
y_pred4=xgb.predict(X_test)
y_pred5=xg.predict(X_test)

# %%
#Evaluating the algorithm                                                                                                                                                                                                                                             
score1=metrics.r2_score(Y_test,y_pred1)
score2=metrics.r2_score(Y_test,y_pred2)
score3=metrics.r2_score(Y_test,y_pred3)
score4=metrics.r2_score(Y_test,y_pred4)
score5=metrics.r2_score(Y_test,y_pred5)

# %% [markdown]
# print(score1,score2,score3,score4,score5)

# %%
print(score1,score2,score3,score4,score5)
# Out:
# 1.0 0.9914741162451437 0.9999908418743099 0.9999542215652419 0.9993838846412267

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
MSE1=mean_squared_error(Y_test,y_pred1)
MSE2=mean_squared_error(Y_test,y_pred2)
MSE3=mean_squared_error(Y_test,y_pred3)
MSE4=mean_squared_error(Y_test,y_pred4)
MSE5=mean_squared_error(Y_test,y_pred5)

MAE1=mean_absolute_error(Y_test,y_pred1)
MAE2=mean_absolute_error(Y_test,y_pred2)
MAE3=mean_absolute_error(Y_test,y_pred3)
MAE4=mean_absolute_error(Y_test,y_pred4)
MAE5=mean_absolute_error(Y_test,y_pred5)

# %%
print(MSE1,MSE2,MSE3,MSE4,MSE5) # MSE

print(MAE1,MAE2,MAE3,MAE4,MAE5) # MAE
# Out:
# 7.236694884842636e-27 0.10580639155030071 0.00011365252688170778 0.000568111310432398 0.007646004187353342
# 5.652007280017986e-14 0.2570316963631572 0.0015693548387259698 0.015570663900392199 0.015602782845680088

# %%
final_score=pd.DataFrame({'Models': ['lr','las','rf','xgb','xg'],
"R2_Score" : [score1,score2,score3,score4,score5]})

# %%
final_score
# Out:
#   Models  R2_Score
# 0     lr  1.000000
# 1    las  0.991474
# 2     rf  0.999991
# 3    xgb  0.999954
# 4     xg  0.999384

# %% [markdown]
# Save the model

# %%
rf=RandomForestRegressor()
rf_final=rf.fit(X,Y)

# %%
lr=LinearRegression()
lr_final=lr.fit(X,Y)

# %%
import joblib

# %%
joblib.dump(rf_final,'car_price_preditor_rf')
# Out:
# ['car_price_preditor_rf']

# %%
joblib.dump(lr_final,'car_price_predictor')
# Out:
# ['car_price_predictor']

# %%
# load the model from disk
model=joblib.load('car_price_predictor')

# %%
model2=joblib.load('car_price_preditor_rf')

# %%
result = model.score(X, Y)

# %%
result2=model2.score(X,Y)

# %%
#import pickle
#pickle.dump(model,open("lrmodel.pkl","wb"))

# %% [markdown]
# Prediction on New data

# %%
newvalue=[[4,5,120687,1,1,1,2015,14.8,1,1196]]

# %%
data_new=pd.DataFrame({
    'FuelType':4,	
    'BodyType':5,	
    'KmsDriven':120687,
    'Transmission':1,
    'OwnerNo':1,
    'ModelBrand':1,
    'ModelYear':2015,
    'Mileage':5.37,
    'City':1,
    'Engine':1196
},index=[0])

# %%
print(data_new)
# Out:
#    FuelType  BodyType  KmsDriven  Transmission  OwnerNo  ModelBrand  \
# 0         4         5     120687             1        1           1
#
#    ModelYear  Mileage  City  Engine
# 0       2015     5.37     1    1196

# %%
result2=model.predict(newvalue)
print(result2)

#new_input = [[10, 20, 30, 40, 50]]  # Input values for prediction
#prediction = model.predict(new_input)
#print("Predicted output:", prediction)
# Out:
# [14.8]
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result2=model2.predict(newvalue)
result2
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([14.8])

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6509 entries, 0 to 6509
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FuelType      6509 non-null   int64
#  1   BodyType      6509 non-null   int64
#  2   KmsDriven     6509 non-null   int64
#  3   Transmission  6509 non-null   int64
#  4   OwnerNo       6509 non-null   int64
#  5   ModelBrand    6509 non-null   int64
#  6   ModelYear     6509 non-null   int64
#  7   Price         6509 non-null   float64
#  8   Mileage       6509 non-null   float64
#  9   City          6509 non-null   int64
#  10  Engine        6509 non-null   int64
# dtypes: float64(2), int64(9)
# memory usage: 610.2 KB

# %%
finaldf.Price
# Out:
# 0       15.37
# 1       20.00
# 2       19.81
# 3       18.70
# 4       13.00
#         ...
# 6505    12.55
# 6506    15.00
# 6507    19.40
# 6508    22.54
# 6509    18.90
# Name: Price, Length: 6509, dtype: float64
